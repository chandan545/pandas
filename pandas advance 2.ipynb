# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", header = None)

# %%
df
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.head()
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
df.tail()
# Out:
#       0  1  2                                         3       4    5  6  7   \
# 887  887  0  2                     Montvila, Rev. Juozas    male   27  0  0
# 888  888  1  1              Graham, Miss. Margaret Edith  female   19  0  0
# 889  889  0  3  Johnston, Miss. Catherine Helen "Carrie"  female  NaN  1  2
# 890  890  1  1                     Behr, Mr. Karl Howell    male   26  0  0
# 891  891  0  3                       Dooley, Mr. Patrick    male   32  0  0
#
#              8      9     10 11
# 887      211536     13   NaN  S
# 888      112053     30   B42  S
# 889  W./C. 6607  23.45   NaN  S
# 890      111369     30  C148  C
# 891      370376   7.75   NaN  Q

# %%
df.shape
# Out:
# (892, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       892 non-null    object
#  1   1       892 non-null    object
#  2   2       892 non-null    object
#  3   3       892 non-null    object
#  4   4       892 non-null    object
#  5   5       715 non-null    object
#  6   6       892 non-null    object
#  7   7       892 non-null    object
#  8   8       892 non-null    object
#  9   9       892 non-null    object
#  10  10      205 non-null    object
#  11  11      890 non-null    object
# dtypes: object(12)
# memory usage: 83.8+ KB

# %%
df.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# dtype: object

# %%
df
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df[0:100]
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 1             1         0       3
# 2             2         1       1
# 3             3         1       3
# 4             4         1       1
# ..          ...       ...     ...
# 95           95         0       3
# 96           96         0       3
# 97           97         0       1
# 98           98         1       1
# 99           99         1       2
#
#                                                    3       4    5      6   \
# 0                                                Name     Sex  Age  SibSp
# 1                             Braund, Mr. Owen Harris    male   22      1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                              Heikkinen, Miss. Laina  female   26      0
# 4        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                ...     ...  ...    ...
# ...

# %%
df[0:100:5]
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 5             5         0       3
# 10           10         1       2
# 15           15         0       3
# 20           20         1       3
# 25           25         0       3
# 30           30         0       3
# 35           35         0       1
# 40           40         1       3
# 45           45         1       3
# 50           50         0       3
# 55           55         0       1
# 60           60         0       3
# 65           65         0       1
# 70           70         0       3
# 75           75         1       3
# 80           80         1       3
# 85           85         1       2
# 90           90         0       3
# 95           95         0       3
#
#                                                3       4    5      6      7   \
# 0                                            Name     Sex  Age  SibSp  Parch
# ...

# %%
#access rows and columns of a dataframe >> implicit/integer/internal indexing, explicit or named indexing

# %%
#iloc
df.iloc[0:3] #start form 0 and go till 2
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#       7          8        9      10        11
# 0  Parch     Ticket     Fare  Cabin  Embarked
# 1      0  A/5 21171     7.25    NaN         S
# 2      0   PC 17599  71.2833    C85         C

# %%
df.loc[0:3] #loc is used for named indexes, iloc is used for integer index
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S

# %%
df.iloc[0:2, ["Name", "Sex"]]  #it will throw an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df.iloc[0:2, ["Name", "Sex"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# ...

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.loc[0:2, ["Name", "Sex"]]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female

# %%
df.iloc[0:2, 3:5]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
df['Name'][2:5]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
#making it into series

# %%
s = pd.Series(list(df['Name'][2:5]), index = ['a', 'b', 'c'])  #first series

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]))

# %%
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
"pw" + "skills"
# Out:
# 'pwskills'

# %%
#series with different indexes and dataframe can not be concatenated using "+"
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
#if you keep indexes same, then for series concatenation can happen

# %%
s1 = pd.Series(list(df['Name'][5:8]), index = ['a', 'b', 'c'])
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s + s1
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop('PassengerId', axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#axis = 0 means drop from rows, axis = 1 means drop from columns, inplace=True modify the original data frame

# %%
df.drop(1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
#set a new index
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %%
df[0:10]
# Out:
#                                                    Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                   0       3    male
# Heikkinen, Miss. Laina                                    1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              1       1  female
# Allen, Mr. William Henry                                  0       3    male
# Moran, Mr. James                                          0       3    male
# McCarthy, Mr. Timothy J                                   0       1    male
# Palsson, Master. Gosta Leonard                            0       3    male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3  female
# Nasser, Mrs. Nicholas (Adele Achem)                       1       2  female
# Sandstrom, Miss. Marguerite Rut                           1       3  female
#
#                                                     Age  SibSp  Parch  \
# Name
# ...

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# Survived            0
# Pclass              3
# Sex              male
# Age              22.0
# SibSp               1
# Parch               0
# Ticket      A/5 21171
# Fare             7.25
# Cabin             NaN
# Embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.reset_index()
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
#making a data frame from a dictionary

# %%
d = {'key1' : [2, 3, 4],
     'key2' : [5, 6, 7],
     'key3' : [8, 9, 10]}
d
# Out:
# {'key1': [2, 3, 4], 'key2': [5, 6, 7], 'key3': [8, 9, 10]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
d = {'key1' : (2, 3, 4),
     'key2' : (5, 6, 7),
     'key3' : (8, 9, 10)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
df1 = pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.dropna() #remove null values from rows
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1) #remove all columns having null values
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis = 1) #for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
#imputation of missing values>> replacing missing values with some values
#numeric data>> mean and median>> outlier(abnormal) value treatment is done, then use mean
#categorical data>> mode
#impute missing with some constant, i.e-0

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("somevalue")  ##replace NaN value with "somevalue"
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  somevalue             somevalue
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}

# %%
df2 = pd.DataFrame(data1)

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2['A'].mean()
# Out:
# 5.75

# %%
df2['B'].mean()
# Out:
# 14.857142857142858

# %%
df2['A'].fillna(df2['A'].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2['A'].median()
# Out:
# 6.0

# %%
df2['A'].fillna(df2['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna("some value")
# Out:
#             A           B
# 0         1.0  some value
# 1         2.0        11.0
# 2  some value        12.0
# 3         4.0        13.0
# 4         5.0  some value
# 5  some value        15.0
# 6         7.0        16.0
# 7         8.0  some value
# 8         9.0        18.0
# 9        10.0        19.0

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method = "ffill") #forward fill>> start seeing from the bottom of dataframe and fill with the next observed value
# Out:
# C:\Users\Chandan Singh\AppData\Local\Temp\ipykernel_24744\3862380551.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method = "ffill") #forward fill>> start seeing from the bottom of dataframe and fill with the next observed value
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method = "bfill") #backward fill>> start seeing from the top of data frame and fill with the next observed value
# Out:
# C:\Users\Chandan Singh\AppData\Local\Temp\ipykernel_24744\2056418194.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method = "bfill") #backward fill>> start seeing from the top of data frame and fill with the next observed value
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
#checking duplicate rows
df2.duplicated().sum()
# Out:
# 0

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.mean() #to see mean value of all columns
# Out:
# A     5.750000
# B    14.857143
# dtype: float64

# %%
df2.median() #to see median of all columns
# Out:
# A     6.0
# B    15.0
# dtype: float64

# %%
df2.std()
# Out:
# A    3.284161
# B    3.023716
# dtype: float64

# %%
df2.A.describe()
# Out:
# count     8.000000
# mean      5.750000
# std       3.284161
# min       1.000000
# 25%       3.500000
# 50%       6.000000
# 75%       8.250000
# max      10.000000
# Name: A, dtype: float64

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#    index     A     B
# 0      0   1.0   NaN
# 1      1   2.0  11.0
# 2      2   NaN  12.0
# 3      3   4.0  13.0
# 4      4   5.0   NaN
# 5      5   NaN  15.0
# 6      6   7.0  16.0
# 7      7   8.0   NaN
# 8      8   9.0  18.0
# 9      9  10.0  19.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
#Q. What is the average fare paid by the people who survived?

# %%
df[df['Survived'] == 1] #people who survived
# Out:
#                                                   Name  Survived  Pclass  \
# 1                               Heikkinen, Miss. Laina         1       3
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 7    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                  Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                      Sandstrom, Miss. Marguerite Rut         1       3
# ..                                                 ...       ...     ...
# 874                   Najib, Miss. Adele Kiamie "Jane"         1       3
# 878      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 879       Shelley, Mrs. William (Imanita Parrish Hall)         1       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 888                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Survived'] == 1]['Fare']
# Out:
# 1       7.9250
# 2      53.1000
# 7      11.1333
# 8      30.0708
# 9      16.7000
#         ...
# 874     7.2250
# 878    83.1583
# 879    26.0000
# 886    30.0000
# 888    30.0000
# Name: Fare, Length: 341, dtype: float64

# %%
df[df['Survived'] == 1]['Fare'].mean()
# Out:
# 48.32828768328446

# %%
#avg fare who did not survived
df[df['Survived'] == 0]['Fare'].mean()
# Out:
# 22.117886885245902

# %%
#Q. What is the average age of people who survived?

# %%
df[df['Survived'] == 1]['Age'].mean()
# Out:
# 28.310276816608997

# %%
#Q. What is the average age of people who did not survived?

# %%
df[df['Survived'] == 0]['Age'].mean()
# Out:
# 30.62617924528302

# %%
df[df['Survived'] == 1]['Fare'].max() #maximum fare
# Out:
# 512.3292

# %%
df[df['Survived'] == 1]['Fare'].min() #minimum fare
# Out:
# 0.0

# %%
#what if max, min, std age/fare in one result
#groupby

# %%
df.groupby('Survived').mean(numeric_only = True)
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.310277  0.472141  0.466276  48.328288

# %%
df.groupby('Survived').sum(numeric_only = True)
# Out:
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8181.67    161    159  16479.9461

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                 Age  \
#           count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ... Parch        Fare                             \
#                mean  ...   75%  max  count       mean        std  min
# Survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.310277  ...   1.0  5.0  341.0  48.328288  66.683277  0.0
#
#
#               25%   50%   75%       max
# Survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
df[['Survived', 'Fare']]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1   7.9250
# 2           1  53.1000
# 3           0   8.0500
# 4           0   8.4583
# ..        ...      ...
# 885         0  13.0000
# 886         1  30.0000
# 887         0  23.4500
# 888         1  30.0000
# 889         0   7.7500
#
# [890 rows x 2 columns]

# %%
import numpy as np
df.groupby(['Survived'])['Fare'].agg(['min', 'max', 'mean', 'median', 'count', np.std, 'var'])
# Out:
# C:\Users\Chandan Singh\AppData\Local\Temp\ipykernel_24744\378349086.py:2: FutureWarning: The provided callable <function std at 0x00000217939D2700> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(['Survived'])['Fare'].agg(['min', 'max', 'mean', 'median', 'count', np.std, 'var'])
#           min       max       mean  median  count        std          var
# Survived
# 0         0.0  263.0000  22.117887    10.5    549  31.388207   985.219509
# 1         0.0  512.3292  48.328288    26.0    341  66.683277  4446.659477

# %%
#how many passengers survived/no survived for each sex and pclass
df.groupby(['Sex', 'Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame().reset_index()
# Out:
#       Sex  Pclass  Survived
# 0  female       1        90
# 1  female       2        70
# 2  female       3        72
# 3    male       1        45
# 4    male       2        17
# 5    male       3        47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47

# %%
df.groupby('Pclass').sum(numeric_only = True)
# Out:
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7073.42     89     77  18106.1292
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
a = df.groupby('Pclass').sum(numeric_only = True)

# %%
a
# Out:
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7073.42     89     77  18106.1292
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
a.T
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6714.6951

# %%
a.transpose()
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6714.6951

# %%
df.head().T
# Out:
#                                 0                       1  \
# Name      Braund, Mr. Owen Harris  Heikkinen, Miss. Laina
# Survived                        0                       1
# Pclass                          3                       3
# Sex                          male                  female
# Age                          22.0                    26.0
# SibSp                           1                       0
# Parch                           0                       0
# Ticket                  A/5 21171        STON/O2. 3101282
# Fare                         7.25                   7.925
# Cabin                         NaN                     NaN
# Embarked                        S                       S
#
#                                                      2  \
# Name      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Survived                                             1
# Pclass                                               1
# ...

# %%
df.tail().T
# Out:
#                             885                           886  \
# Name      Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# Survived                      0                             1
# Pclass                        2                             1
# Sex                        male                        female
# Age                        27.0                          19.0
# SibSp                         0                             0
# Parch                         0                             0
# Ticket                   211536                        112053
# Fare                       13.0                          30.0
# Cabin                       NaN                           B42
# Embarked                      S                             S
#
#                                                887                    888  \
# Name      Johnston, Miss. Catherine Helen "Carrie"  Behr, Mr. Karl Howell
# ...
